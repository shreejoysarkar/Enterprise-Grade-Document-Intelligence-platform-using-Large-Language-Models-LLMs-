# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Enterprise-Grade-Document-Intelligence-platform-using-Large-Language-Models-LLMs-\\experiments'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Enterprise-Grade-Document-Intelligence-platform-using-Large-Language-Models-LLMs-'

# %%
from core.doc_processor import DocumentProcessor

# %%
processor = DocumentProcessor()
processor.process_all()
# Out:
# CUDA is not available in the system. Fall back to 'CPU'
# CUDA is not available in the system. Fall back to 'CPU'
# Found 1 PDF files to process in Data\Input.
# Processing: aapl-20230930.pdf...
# Loading weights: 100%|██████████| 471/471 [00:00<00:00, 7860.25it/s]
# CUDA is not available in the system. Fall back to 'CPU'
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 7001.46it/s]
# CUDA is not available in the system. Fall back to 'CPU'
# ✅ Successfully saved: aapl-20230930.md
#
# 🎉 All processing complete!
# ✅ Successful: 1 | ❌ Failed: 0
